# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import seaborn as sns

# %%
df_22 = pd.read_csv('state_NY_22.csv')
# Out:
# C:\Users\PanSt\AppData\Local\Temp\ipykernel_4564\2927935134.py:1: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22 = pd.read_csv('state_NY_22.csv')

# %%
df = df_22.drop(columns=[
'applicant_age_above_62','co-applicant_age_above_62',
    'aus-2', 'aus-3', 'aus-4', 'aus-5',
    'denial_reason-2', 'denial_reason-3','denial_reason-4', 
    'activity_year', 'total_points_and_fees','county_code',
    'lei', 'multifamily_affordable_units', 'prepayment_penalty_term', 'state_code',
    'applicant_race-1','applicant_race-2', 'applicant_race-3','applicant_race-4', 'applicant_race-5', 'co-applicant_race-2', 'co-applicant_race-3', 'co-applicant_race-4','co-applicant_race-5', 'co-applicant_race_observed', 'co-applicant_sex_observed', 'applicant_race_observed' ,'co-applicant_race-1', 'co-applicant_sex',
    'applicant_sex','applicant_sex_observed',
    'applicant_ethnicity-1','applicant_ethnicity-2','applicant_ethnicity-3', 'applicant_ethnicity-4','applicant_ethnicity-5','applicant_ethnicity_observed', 'co-applicant_ethnicity-1','co-applicant_ethnicity-2', 'co-applicant_ethnicity-3','co-applicant_ethnicity-4', 'co-applicant_ethnicity-5', 'co-applicant_ethnicity_observed', 
    'construction_method',
    'lien_status','loan_type',
    'ffiec_msa_md_median_family_income', 'derived_msa-md',
    'tract_one_to_four_family_homes', 'submission_of_application', 'occupancy_type', 'other_nonamortizing_features', 
    'derived_msa-md',
    'discount_points', 'lender_credits', 'intro_rate_period'
])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548905 entries, 0 to 548904
# Data columns (total 43 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   census_tract                              545678 non-null  float64
#  1   conforming_loan_limit                     542121 non-null  object
#  2   derived_loan_product_type                 548905 non-null  object
#  3   derived_dwelling_category                 548905 non-null  object
#  4   derived_ethnicity                         548905 non-null  object
#  5   derived_race                              548905 non-null  object
#  6   derived_sex                               548905 non-null  object
#  7   action_taken                              548905 non-null  int64
#  8   purchaser_type                            548905 non-null  int64
#  9   preapproval                               548905 non-null  int64
#  10  loan_purpose                              548905 non-null  int64
#  11  reverse_mortgage                          548905 non-null  int64
#  12  open-end_line_of_credit                   548905 non-null  int64
#  13  business_or_commercial_purpose            548905 non-null  int64
#  14  loan_amount                               548905 non-null  float64
#  15  loan_to_value_ratio                       403310 non-null  object
#  16  interest_rate                             371823 non-null  object
#  17  rate_spread                               292870 non-null  object
#  18  hoepa_status                              548905 non-null  int64
#  19  total_loan_costs                          271976 non-null  object
#  20  origination_charges                       274206 non-null  object
#  21  loan_term                                 537232 non-null  object
#  22  negative_amortization                     548905 non-null  int64
#  23  interest_only_payment                     548905 non-null  int64
#  24  balloon_payment                           548905 non-null  int64
#  25  property_value                            458526 non-null  object
#  26  manufactured_home_secured_property_type   548905 non-null  int64
#  27  manufactured_home_land_property_interest  548905 non-null  int64
#  28  total_units                               548905 non-null  object
#  29  income                                    494256 non-null  float64
#  30  debt_to_income_ratio                      392729 non-null  object
#  31  applicant_credit_score_type               548905 non-null  int64
#  32  co-applicant_credit_score_type            548905 non-null  int64
#  33  applicant_age                             548905 non-null  object
#  34  co-applicant_age                          548905 non-null  object
#  35  initially_payable_to_institution          548905 non-null  int64
#  36  aus-1                                     548905 non-null  int64
#  37  denial_reason-1                           548905 non-null  int64
#  38  tract_population                          548905 non-null  int64
#  39  tract_minority_population_percent         548905 non-null  float64
#  40  tract_to_msa_income_percentage            548905 non-null  int64
#  41  tract_owner_occupied_units                548905 non-null  int64
#  42  tract_median_age_of_housing_units         548905 non-null  int64
# dtypes: float64(4), int64(22), object(17)
# memory usage: 180.1+ MB

# %%
obj_columns = df.select_dtypes(include=['object'])
obj_columns
# Out:
#        conforming_loan_limit derived_loan_product_type
# 0                          C   Conventional:First Lien  \
# 1                          C   Conventional:First Lien
# 2                          C   Conventional:First Lien
# 3                          U   Conventional:First Lien
# 4                          U   Conventional:First Lien
# ...                      ...                       ...
# 548900                     C   Conventional:First Lien
# 548901                     C   Conventional:First Lien
# 548902                     C   Conventional:First Lien
# 548903                    NC   Conventional:First Lien
# 548904                     C   Conventional:First Lien
#
#                      derived_dwelling_category        derived_ethnicity
# 0       Single Family (1-4 Units):Manufactured   Not Hispanic or Latino  \
# 1         Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 2         Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 3         Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 4         Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# ...                                        ...                      ...
# 548900    Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 548901    Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 548902    Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 548903    Single Family (1-4 Units):Site-Built  Ethnicity Not Available
# 548904  Single Family (1-4 Units):Manufactured   Not Hispanic or Latino
#
#                                      derived_race        derived_sex
# 0       Native Hawaiian or Other Pacific Islander              Joint  \
# 1                              Race Not Available  Sex Not Available
# 2                              Race Not Available  Sex Not Available
# 3                              Race Not Available  Sex Not Available
# 4                              Race Not Available  Sex Not Available
# ...                                           ...                ...
# 548900                         Race Not Available  Sex Not Available
# 548901                         Race Not Available  Sex Not Available
# 548902                         Race Not Available  Sex Not Available
# 548903                         Race Not Available  Sex Not Available
# 548904                  Black or African American             Female
#
#        loan_to_value_ratio interest_rate rate_spread total_loan_costs
# 0                      NaN           NaN         NaN              NaN  \
# 1                      NaN           NaN         NaN              NaN
# 2                      NaN           NaN         NaN              NaN
# 3                      NaN           NaN         NaN              NaN
# 4                      NaN           NaN         NaN              NaN
# ...                    ...           ...         ...              ...
# 548900                 NaN          6.75         NaN              NaN
# 548901                 NaN           NaN         NaN              NaN
# 548902                 NaN           NaN         NaN              NaN
# 548903                 NaN           NaN         NaN              NaN
# 548904                 NaN           NaN         NaN              NaN
#
#        origination_charges loan_term property_value total_units
# 0                      NaN       300       125000.0           1  \
# 1                      NaN       360       265000.0           1
# 2                      NaN       360            NaN           1
# 3                      NaN       360            NaN           4
# 4                      NaN       360      1175000.0           1
# ...                    ...       ...            ...         ...
# 548900                 NaN       360       275000.0           2
# 548901                 NaN       360            NaN           4
# 548902                 NaN       360            NaN           1
# 548903                 NaN       360      1435000.0           1
# 548904                 NaN       360        55000.0           1
#
#        debt_to_income_ratio applicant_age co-applicant_age
# 0                      >60%         45-54            35-44
# 1                       NaN          8888             9999
# 2                       NaN          8888             9999
# 3                       NaN          8888             9999
# 4                       NaN          8888             9999
# ...                     ...           ...              ...
# 548900                  NaN          8888             9999
# 548901                  NaN          8888             9999
# 548902                  NaN          8888             9999
# 548903                  NaN          8888             9999
# 548904                 <20%         25-34             9999
#
# [548905 rows x 17 columns]

# %% [markdown]
# ## Object features casting ##

# %%
num_columns = list(filter(lambda col: (df[col] == 'Exempt').any(), obj_columns))
cat_columns = list(filter(lambda col: not (df[col] == 'Exempt').any(), obj_columns))
num_columns, cat_columns
# Out:
# (['loan_to_value_ratio',
#   'interest_rate',
#   'rate_spread',
#   'total_loan_costs',
#   'origination_charges',
#   'loan_term',
#   'property_value',
#   'debt_to_income_ratio'],
#  ['conforming_loan_limit',
#   'derived_loan_product_type',
#   'derived_dwelling_category',
#   'derived_ethnicity',
#   'derived_race',
#   'derived_sex',
#   'total_units',
#   'applicant_age',
#   'co-applicant_age'])

# %%
df_no_exempt = df.replace({col: {'Exempt': np.nan} for col in num_columns})
df_no_exempt = df_no_exempt.replace(
{'debt_to_income_ratio': { #replacement with mean of interval
    '<20%': 0.1,
    '20%-<30%': 0.25,
    '30%-<36%': 0.33,
    '36': 0.36,
    '37': 0.37,
    '38': 0.38,
    '39': 0.39,
    '40': 0.40,
    '41': 0.41,
    '42': 0.42,
    '43': 0.43,
    '44': 0.44,
    '45': 0.45,
    '46': 0.46,
    '47': 0.47,
    '48': 0.48,
    '49': 0.49,
    '50%-60%': 0.55,
    '>60%': 0.8
},
 'total_loan_costs': {np.nan: 0.},
 'origination_charges': {np.nan: 0.}
}
)
df_no_exempt[num_columns] = df_no_exempt[num_columns].apply(pd.to_numeric)
df_no_exempt = df_no_exempt[df_no_exempt['denial_reason-1'] != 1111]
#todo: replace object categorical variables with int64 numbers (0,1..n)

# %%
df_no_exempt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539194 entries, 0 to 548904
# Data columns (total 43 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   census_tract                              536752 non-null  float64
#  1   conforming_loan_limit                     533402 non-null  object
#  2   derived_loan_product_type                 539194 non-null  object
#  3   derived_dwelling_category                 539194 non-null  object
#  4   derived_ethnicity                         539194 non-null  object
#  5   derived_race                              539194 non-null  object
#  6   derived_sex                               539194 non-null  object
#  7   action_taken                              539194 non-null  int64
#  8   purchaser_type                            539194 non-null  int64
#  9   preapproval                               539194 non-null  int64
#  10  loan_purpose                              539194 non-null  int64
#  11  reverse_mortgage                          539194 non-null  int64
#  12  open-end_line_of_credit                   539194 non-null  int64
#  13  business_or_commercial_purpose            539194 non-null  int64
#  14  loan_amount                               539194 non-null  float64
#  15  loan_to_value_ratio                       387896 non-null  float64
#  16  interest_rate                             356284 non-null  float64
#  17  rate_spread                               277694 non-null  float64
#  18  hoepa_status                              539194 non-null  int64
#  19  total_loan_costs                          539194 non-null  float64
#  20  origination_charges                       539194 non-null  float64
#  21  loan_term                                 521607 non-null  float64
#  22  negative_amortization                     539194 non-null  int64
#  23  interest_only_payment                     539194 non-null  int64
#  24  balloon_payment                           539194 non-null  int64
#  25  property_value                            443054 non-null  float64
#  26  manufactured_home_secured_property_type   539194 non-null  int64
#  27  manufactured_home_land_property_interest  539194 non-null  int64
#  28  total_units                               539194 non-null  object
#  29  income                                    487061 non-null  float64
#  30  debt_to_income_ratio                      377554 non-null  float64
#  31  applicant_credit_score_type               539194 non-null  int64
#  32  co-applicant_credit_score_type            539194 non-null  int64
#  33  applicant_age                             539194 non-null  object
#  34  co-applicant_age                          539194 non-null  object
#  35  initially_payable_to_institution          539194 non-null  int64
#  36  aus-1                                     539194 non-null  int64
#  37  denial_reason-1                           539194 non-null  int64
#  38  tract_population                          539194 non-null  int64
#  39  tract_minority_population_percent         539194 non-null  float64
#  40  tract_to_msa_income_percentage            539194 non-null  int64
#  41  tract_owner_occupied_units                539194 non-null  int64
#  42  tract_median_age_of_housing_units         539194 non-null  int64
# dtypes: float64(12), int64(22), object(9)
# memory usage: 181.0+ MB

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df_no_exempt.isnull(), yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# 14.04: Further cleanup

# %% [markdown]
# 1.Dropping rows with nan

# %%
from typing import List

columns_to_drop_nan: List[str] = [
    'conforming_loan_limit',
    'census_tract',
    'loan_term',
    'income'
]

df_22.dropna(subset=columns_to_drop_nan, inplace=True)
df_22
# Out:
#         activity_year                   lei  derived_msa-md state_code
# 0                2022  5493000YNV8IX4VD3X12           35614         NY  \
# 141              2022  KD3XUN7C6T14HNAYLU02           35614         NY
# 142              2022  KD3XUN7C6T14HNAYLU02           35614         NY
# 143              2022  KD3XUN7C6T14HNAYLU02           35614         NY
# 144              2022  KD3XUN7C6T14HNAYLU02           35614         NY
# ...               ...                   ...             ...        ...
# 548896           2022  549300VN9E1DEKF26E34           35614         NY
# 548897           2022  549300VN9E1DEKF26E34           35004         NY
# 548898           2022  549300VN9E1DEKF26E34           35004         NY
# 548899           2022  549300VN9E1DEKF26E34           35614         NY
# 548904           2022  5493000YNV8IX4VD3X12           99999         NY
#
#         county_code  census_tract conforming_loan_limit
# 0           36005.0  3.600505e+10                     C  \
# 141         36061.0  3.606101e+10                    NC
# 142         36061.0  3.606101e+10                    NC
# 143         36061.0  3.606101e+10                    NC
# 144         36061.0  3.606100e+10                    NC
# ...             ...           ...                   ...
# 548896      36061.0  3.606102e+10                     C
# 548897      36103.0  3.610316e+10                     C
# 548898      36103.0  3.610320e+10                    NC
# 548899      36081.0  3.608107e+10                     C
# 548904      36049.0  3.604995e+10                     C
#
#             derived_loan_product_type               derived_dwelling_category
# 0             Conventional:First Lien  Single Family (1-4 Units):Manufactured  \
# 141           Conventional:First Lien    Single Family (1-4 Units):Site-Built
# 142           Conventional:First Lien    Single Family (1-4 Units):Site-Built
# 143           Conventional:First Lien    Single Family (1-4 Units):Site-Built
# 144           Conventional:First Lien    Single Family (1-4 Units):Site-Built
# ...                               ...                                     ...
# 548896  Conventional:Subordinate Lien    Single Family (1-4 Units):Site-Built
# 548897  Conventional:Subordinate Lien    Single Family (1-4 Units):Site-Built
# 548898  Conventional:Subordinate Lien    Single Family (1-4 Units):Site-Built
# 548899  Conventional:Subordinate Lien    Single Family (1-4 Units):Site-Built
# 548904        Conventional:First Lien  Single Family (1-4 Units):Manufactured
#
#               derived_ethnicity  ... denial_reason-2 denial_reason-3
# 0        Not Hispanic or Latino  ...             NaN             NaN  \
# 141     Ethnicity Not Available  ...             NaN             NaN
# 142     Ethnicity Not Available  ...             NaN             NaN
# 143      Not Hispanic or Latino  ...             NaN             NaN
# 144     Ethnicity Not Available  ...             NaN             NaN
# ...                         ...  ...             ...             ...
# 548896  Ethnicity Not Available  ...             NaN             NaN
# 548897  Ethnicity Not Available  ...             NaN             NaN
# 548898   Not Hispanic or Latino  ...             NaN             NaN
# 548899       Hispanic or Latino  ...             9.0             NaN
# 548904   Not Hispanic or Latino  ...             9.0             NaN
#
#         denial_reason-4  tract_population  tract_minority_population_percent
# 0                   NaN              2142                              32.31  \
# 141                 NaN              5698                              36.17
# 142                 NaN              6180                              19.71
# 143                 NaN              5698                              36.17
# 144                 NaN              2989                              57.51
# ...                 ...               ...                                ...
# 548896              NaN              5127                              93.21
# 548897              NaN              8067                              22.47
# 548898              NaN              1941                              21.48
# 548899              NaN              5423                              97.49
# 548904              NaN              1245                               5.46
#
#         ffiec_msa_md_median_family_income  tract_to_msa_income_percentage
# 0                                   99000                             109  \
# 141                                 99000                             244
# 142                                 99000                             292
# 143                                 99000                             244
# 144                                 99000                             284
# ...                                   ...                             ...
# 548896                              99000                              54
# 548897                             146400                              94
# 548898                             146400                             159
# 548899                              99000                             110
# 548904                              76700                              89
#
#         tract_owner_occupied_units  tract_one_to_four_family_homes
# 0                              339                             411  \
# 141                            693                              47
# 142                            711                             685
# 143                            693                              47
# 144                            208                               7
# ...                            ...                             ...
# 548896                          51                              68
# 548897                        2163                            2404
# 548898                         724                            1488
# 548899                         864                            1638
# 548904                         442                             670
#
#         tract_median_age_of_housing_units
# 0                                      70
# 141                                    40
# 142                                     0
# 143                                    40
# 144                                    19
# ...                                   ...
# 548896                                 67
# 548897                                 27
# 548898                                 33
# 548899                                 63
# 548904                                 47
#
# [481773 rows x 99 columns]

# %%
assert not df_22[columns_to_drop_nan].isnull().values.any(), "NaN values still exist in columns_to_drop_nan"
column_with_nan = df_22.columns[df_22.isna().any()].tolist()

for col in column_with_nan:
    print(col)
# Out:
# county_code
# loan_to_value_ratio
# interest_rate
# rate_spread
# total_loan_costs
# total_points_and_fees
# origination_charges
# discount_points
# lender_credits
# prepayment_penalty_term
# intro_rate_period
# property_value
# multifamily_affordable_units
# debt_to_income_ratio
# applicant_ethnicity-1
# applicant_ethnicity-2
# applicant_ethnicity-3
# applicant_ethnicity-4
# applicant_ethnicity-5
# co-applicant_ethnicity-1
# co-applicant_ethnicity-2
# co-applicant_ethnicity-3
# co-applicant_ethnicity-4
# co-applicant_ethnicity-5
# applicant_race-1
# applicant_race-2
# applicant_race-3
# applicant_race-4
# applicant_race-5
# co-applicant_race-1
# co-applicant_race-2
# co-applicant_race-3
# co-applicant_race-4
# co-applicant_race-5
# applicant_age_above_62
# co-applicant_age_above_62
# aus-2
# aus-3
# aus-4
# aus-5
# denial_reason-2
# denial_reason-3
# denial_reason-4

# %% [markdown]
# 2.Fill in specific missing values with the mean value of their respective columns. We may consider using linear regression, as stated below.

# %%
columns_to_fill_with_mean: List[str] = [
    'loan_to_value_ratio',
    'interest_rate',
    'rate_spread',
    'property_value',
    'debt_to_income_ratio'
]

for column in columns_to_fill_with_mean:
    df_22[column] = pd.to_numeric(df_22[column], errors='coerce')
    mean_value = df_22[column].mean()
    df_22[column].fillna(mean_value, inplace=True)

# %%
for column in columns_to_fill_with_mean:
    assert not df_22[column].isnull().any(), f"Column '{column}' contains NaN values."

# %% [markdown]
# ## Version 1, agregated classification ##

# %%
#agregate denial_reason-1 to 2 classes 1 for 10, 0 for rest
denial_reason_columns = [col for col in df_22.columns if col.startswith('denial_reason')]
df_22['Total_Denials'] = 0
df_22.loc[df_22['denial_reason-1'] > 0, 'Total_Denials'] = 1
df_22.drop(columns=denial_reason_columns, inplace=True)
# Out:
# denial_reason-1
# denial_reason-2
# denial_reason-3
# denial_reason-4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[178], line 8
#       5 for col in denial_reason_columns:
#       6     print(col)
# ----> 8 df_22['Total_Denials'] = df_22[['denial_reason-1', 'denial_reason_2', 'denial_reason_3', 'denial_reason_4']].sum(axis=1)
#      10 # Drop individual denial reason columns
#      11 df_22.drop(columns=['denial_reason-1', 'denial_reason_2', 'denial_reason_3', 'denial_reason_4'], inplace=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['denial_reason_2', 'denial_reason_3', 'denial_reason_4'] not in index"

# %% [markdown]
# ## Train - test dataset split ##

# %%
# TRAIN - TEST SPLIT
from sklearn.model_selection import StratifiedShuffleSplit # random state 0
#train 3:1 test - may change later

# %% [markdown]
# 1. train - random undersampling of dominant class, reduce to 66%
# 2. train - random oversampling of minority class, double it

# %% [markdown]
# # IMPORTANT!!! #
# + random_state=0 wherever possible
# + all gridsearches: cv=10, n_jobs=-1, scoring='roc_auc'
# + ... in params means name of component in pipeline, it is parameter to optimize for that component (see in pum notebook or docs)
# + if metrics are not improving, try different random over/under sampling

# %% [markdown]
# ## Missing values complementation standarization ##
# BOTH TRAIN AND TEST, BUT SEPARATELY
#
# #### What to do with missing values? ####
# + total_loan_costs - replace with 0 - done
# + origination_charges - replace with 0 - done
# + confirming_loan_limit - drop rows with nan - done
# + census_tract - drop rows with nan - done
# + loan_term - drop rows with nan - done
# + income - drop rows with nan - done
# + loan_to_value_ratio - mean - done
# + interest_rate - mean or linear regression - done
# + rate_spread - mean or linear regression - done
# + property_value - mean or linear regression - done
# + debt_to_income_ratio - mean or linear regression - done

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
# fill missing values simpleImpute (happy way - mean, no regression for now)
# one hot encodeing categorical features
# minmax standarization numerical features

# %%
from sklearn.ensemble import RandomForestClassifier
# to test performance, from pum notebook
def assess_rf_performance(estimator: RandomForestClassifier, X_test, y_test) -> None:
    y_score = estimator.predict_proba(X_test)[:, 1]
    y_pred = estimator.predict(X_test)
    auroc = roc_auc_score(y_test, y_score)
    f1 = f1_score(y_test, y_pred)

    print(f"AUROC: {100 * auroc:.2f}%")
    print(f"F1-score: {100 * f1:.2f}%")

# %%
# here train RFC before enn and smote to compare performance

# %% [markdown]
# ## Undersampling ##
# ONLY TRAIN SET
# - ENN + hyperparameters tuning (gridsearch) on RandomForestClassifier(class_weight="balanced", random_state=0, n_jobs=-1)
# - Pipeline with enn step before RFC

# %%
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.model_selection import GridSearchCV # always create new estimator!

param_grid = {"...__n_neighbors": [1, 3, 5], "...__kind_sel": ["all", "mode"]} # to optimize for RandomForestClassifier, experiment with different values

# %% [markdown]
# ## Oversampling ##
# ONLY TRAIN SET
# - SMOTE + hyperparameters tuning (gridsearch) on RandomForestClassifier(class_weight="balanced", random_state=0, n_jobs=-1)
# - Pipeline with smote step before RFC

# %%
from imblearn.over_sampling import SMOTE

param_grid = {"...__k_neighbors": [1, 2, 3, 4, 5]} # to optimize for RandomForestClassifier, experiment with different values

# %% [markdown]
# ## Combined ##
# try combined over & under sampling at once with optimal hyperparameters
# - Pipeline with smoteenn step (with optimal parameters) before RFC

# %%
from imblearn.combine import SMOTEENN
